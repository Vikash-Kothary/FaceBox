# %%
import pymongo
import bson
from PIL import Image
import io
import dotenv
import os

# %%
#
# %load_ext dotenv
# Use find_dotenv to locate the file
# %dotenv
# Out:
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv

# %%
# %reload_ext dotenv
USERNAME = os.getenv("MONGODB_USERNAME")
PASSWORD = os.getenv("MONGODB_PASSWORD")
HOST = os.getenv("MONGODB_HOST")
PORT = os.getenv("MONGODB_PORT")
DBNAME = os.getenv("MONGODB_DBNAME")
TABLENAME = os.getenv("MONGODB_TABLENAME")
URI = f"mongodb://{USERNAME}:{PASSWORD}@{HOST}:{PORT}"
DBNAME is not None
# Out:
# True

# %%
myclient = pymongo.MongoClient(URI)
mydb = myclient[DBNAME]
mycol = mydb[TABLENAME]

# %%
with open("img.jpg", "rb") as image:
  f = image.read()
  b = bytearray(f)
  print(b[0])

# %%
x = mycol.insert_one({'images':bson.BSON(b)})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-5636595229e2> in <module>
# ----> 1 x = mycol.insert_one({'images':bson.BSON(b)})
#
# NameError: name 'mycol' is not defined

# %%
x = mycol.find_one()

# %%
img = Image.open(io.BytesIO(x['images']))

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=100x100 at 0x7F60496F45C0>
